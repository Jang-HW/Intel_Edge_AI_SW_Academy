# %% [markdown]
# # **감정 분류 (Emotion Classification)**

# %% [markdown]
# ## 1.Datasets 로드하고 확인하기

# %% [markdown]
# - You can download FER(Face Emotions Recognition) Datasets from https://www.kaggle.com/datasets/msambare/fer2013

# %% [markdown]
# ### 1-1. 데이터셋 다운로드하기

# %% [markdown]
# ### 방법1) 구글 드라이브에 데이터셋 압축파일로 업로드 후 공유링크에서 다운로드하기

# %%
# 데이터 다운로드하기 - 'fer2013.zip'

# !gdown 1IqZeiM2k_Hyx5VGWEX3DfZKJLKJVd7D7    # ... 코드입력
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1IqZeiM2k_Hyx5VGWEX3DfZKJLKJVd7D7
# From (redirected): https://drive.google.com/uc?id=1IqZeiM2k_Hyx5VGWEX3DfZKJLKJVd7D7&confirm=t&uuid=e944fb7d-3547-46f7-9abb-4d283507c655
# To: /content/archive.zip
# 100% 63.3M/63.3M [00:01<00:00, 62.2MB/s]

# %%
# 다운 받은 압축파일 압축해제하기 : fer2013 디렉토리 하위에 압축 풀기
# !unzip  archive.zip -d ./fer2013    # ... 코드입력
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./fer2013/train/sad/Training_65242339.jpg
#   inflating: ./fer2013/train/sad/Training_65267116.jpg
#   inflating: ./fer2013/train/sad/Training_65275626.jpg
#   inflating: ./fer2013/train/sad/Training_6529266.jpg
#   inflating: ./fer2013/train/sad/Training_65329617.jpg
#   inflating: ./fer2013/train/sad/Training_65338712.jpg
#   inflating: ./fer2013/train/sad/Training_65338797.jpg
#   inflating: ./fer2013/train/sad/Training_65387162.jpg
#   inflating: ./fer2013/train/sad/Training_65404494.jpg
#   inflating: ./fer2013/train/sad/Training_65426218.jpg
#   inflating: ./fer2013/train/sad/Training_65430136.jpg
#   inflating: ./fer2013/train/sad/Training_65437377.jpg
#   inflating: ./fer2013/train/sad/Training_6545735.jpg
#   inflating: ./fer2013/train/sad/Training_65463385.jpg
#   inflating: ./fer2013/train/sad/Training_65473985.jpg
#   inflating: ./fer2013/train/sad/Training_65502829.jpg
#   inflating: ./fer2013/train/sad/Training_65505359.jpg
#   inflating: ./fer2013/train/sad/Training_65508578.jpg
#   inflating: ./fer2013/train/sad/Training_65516023.jpg
#   inflating: ./fer2013/train/sad/Training_65524027.jpg
#   inflating: ./fer2013/train/sad/Training_65526454.jpg
#   inflating: ./fer2013/train/sad/Training_65531175.jpg
#   inflating: ./fer2013/train/sad/Training_65552921.jpg
#   inflating: ./fer2013/train/sad/Training_65552938.jpg
#   inflating: ./fer2013/train/sad/Training_65563105.jpg
#   inflating: ./fer2013/train/sad/Training_6558295.jpg
#   inflating: ./fer2013/train/sad/Training_65586139.jpg
#   inflating: ./fer2013/train/sad/Training_65591252.jpg
#   inflating: ./fer2013/train/sad/Training_65626778.jpg
#   inflating: ./fer2013/train/sad/Training_65701260.jpg
#   inflating: ./fer2013/train/sad/Training_65707197.jpg
#   inflating: ./fer2013/train/sad/Training_65720898.jpg
#   inflating: ./fer2013/train/sad/Training_6573454.jpg
#   inflating: ./fer2013/train/sad/Training_65749670.jpg
#   inflating: ./fer2013/train/sad/Training_65756896.jpg
#   inflating: ./fer2013/train/sad/Training_65792953.jpg
#   inflating: ./fer2013/train/sad/Training_65814968.jpg
#   inflating: ./fer2013/train/sad/Training_65872739.jpg
#   inflating: ./fer2013/train/sad/Training_65887072.jpg
#   inflating: ./fer2013/train/sad/Training_65899637.jpg
#   inflating: ./fer2013/train/sad/Training_65930243.jpg
#   inflating: ./fer2013/train/sad/Training_65931697.jpg
#   inflating: ./fer2013/train/sad/Training_66006689.jpg
#   inflating: ./fer2013/train/sad/Training_66018355.jpg
#   inflating: ./fer2013/train/sad/Training_66025411.jpg
#   inflating: ./fer2013/train/sad/Training_6604778.jpg
#   inflating: ./fer2013/train/sad/Training_66064111.jpg
#   inflating: ./fer2013/train/sad/Training_66092447.jpg
#   inflating: ./fer2013/train/sad/Training_66106251.jpg
#   inflating: ./fer2013/train/sad/Training_6613286.jpg
#   inflating: ./fer2013/train/sad/Training_66137005.jpg
#   inflating: ./fer2013/train/sad/Training_66146242.jpg
#   inflating: ./fer2013/train/sad/Training_66186083.jpg
#   inflating: ./fer2013/train/sad/Training_66222142.jpg
#   inflating: ./fer2013/train/sad/Training_66241554.jpg
#   inflating: ./fer2013/train/sad/Training_66243450.jpg
#   inflating: ./fer2013/train/sad/Training_66270296.jpg
#   inflating: ./fer2013/train/sad/Training_66273436.jpg
#   inflating: ./fer2013/train/sad/Training_6627432.jpg
#   inflating: ./fer2013/train/sad/Training_66292901.jpg
#   inflating: ./fer2013/train/sad/Training_6632070.jpg
#   inflating: ./fer2013/train/sad/Training_66345107.jpg
#   inflating: ./fer2013/train/sad/Training_66358284.jpg
#   inflating: ./fer2013/train/sad/Training_66374624.jpg
#   inflating: ./fer2013/train/sad/Training_66374947.jpg
#   inflating: ./fer2013/train/sad/Training_66449545.jpg
#   inflating: ./fer2013/train/sad/Training_66465496.jpg
#   inflating: ./fer2013/train/sad/Training_66485665.jpg
#   inflating: ./fer2013/train/sad/Training_66503867.jpg
#   inflating: ./fer2013/train/sad/Training_66511942.jpg
#   inflating: ./fer2013/train/sad/Training_66514659.jpg
#   inflating: ./fer2013/train/sad/Training_66538546.jpg
#   inflating: ./fer2013/train/sad/Training_66548047.jpg
#   inflating: ./fer2013/train/sad/Training_66550587.jpg
#   inflating: ./fer2013/train/sad/Training_66564605.jpg
#   inflating: ./fer2013/train/sad/Training_66598359.jpg
#   inflating: ./fer2013/train/sad/Training_6660320.jpg
#   inflating: ./fer2013/train/sad/Training_66613149.jpg
#   inflating: ./fer2013/train/sad/Training_66618356.jpg
#   inflating: ./fer2013/train/sad/Training_66621180.jpg
#   inflating: ./fer2013/train/sad/Training_66632167.jpg
#   inflating: ./fer2013/train/sad/Training_66633227.jpg
#   inflating: ./fer2013/train/sad/Training_66665516.jpg
#   inflating: ./fer2013/train/sad/Training_66670996.jpg
#   inflating: ./fer2013/train/sad/Training_66677994.jpg
#   inflating: ./fer2013/train/sad/Training_66678590.jpg
#   inflating: ./fer2013/train/sad/Training_66688298.jpg
#   inflating: ./fer2013/train/sad/Training_66705535.jpg
#   inflating: ./fer2013/train/sad/Training_66717644.jpg
#   inflating: ./fer2013/train/sad/Training_66723931.jpg
#   inflating: ./fer2013/train/sad/Training_66743020.jpg
#   inflating: ./fer2013/train/sad/Training_66758555.jpg
#   inflating: ./fer2013/train/sad/Training_66776704.jpg
#   inflating: ./fer2013/train/sad/Training_66778513.jpg
#   inflating: ./fer2013/train/sad/Training_66782106.jpg
#   inflating: ./fer2013/train/sad/Training_66801083.jpg
#   inflating: ./fer2013/train/sad/Training_66812358.jpg
#   inflating: ./fer2013/train/sad/Training_66816897.jpg
#   inflating: ./fer2013/train/sad/Training_66834181.jpg
#   inflating: ./fer2013/train/sad/Training_66836105.jpg
#   inflating: ./fer2013/train/sad/Training_66860349.jpg
#   inflating: ./fer2013/train/sad/Training_66885032.jpg
#   inflating: ./fer2013/train/sad/Training_66932713.jpg
#   inflating: ./fer2013/train/sad/Training_66967267.jpg
#   inflating: ./fer2013/train/sad/Training_66980527.jpg
#   inflating: ./fer2013/train/sad/Training_67003784.jpg
#   inflating: ./fer2013/train/sad/Training_67009167.jpg
#   inflating: ./fer2013/train/sad/Training_67015623.jpg
#   inflating: ./fer2013/train/sad/Training_67021882.jpg
#   inflating: ./fer2013/train/sad/Training_6704458.jpg
#   inflating: ./fer2013/train/sad/Training_67046287.jpg
#   inflating: ./fer2013/train/sad/Training_67063417.jpg
#   inflating: ./fer2013/train/sad/Training_67094111.jpg
#   inflating: ./fer2013/train/sad/Training_67118841.jpg
#   inflating: ./fer2013/train/sad/Training_67152521.jpg
#   inflating: ./fer2013/train/sad/Training_6716869.jpg
#   inflating: ./fer2013/train/sad/Training_67169851.jpg
#   inflating: ./fer2013/train/sad/Training_67218522.jpg
#   inflating: ./fer2013/train/sad/Training_67220863.jpg
#   inflating: ./fer2013/train/sad/Training_67244109.jpg
#   inflating: ./fer2013/train/sad/Training_67244736.jpg
#   inflating: ./fer2013/train/sad/Training_67277941.jpg
#   inflating: ./fer2013/train/sad/Training_67317150.jpg
#   inflating: ./fer2013/train/sad/Training_6733844.jpg
#   inflating: ./fer2013/train/sad/Training_67341114.jpg
#   inflating: ./fer2013/train/sad/Training_67345736.jpg
#   inflating: ./fer2013/train/sad/Training_6736373.jpg
#   inflating: ./fer2013/train/sad/Training_6736561.jpg
#   inflating: ./fer2013/train/sad/Training_67385672.jpg
#   inflating: ./fer2013/train/sad/Training_67400475.jpg
#   inflating: ./fer2013/train/sad/Training_67405401.jpg
#   inflating: ./fer2013/train/sad/Training_67418316.jpg
#   inflating: ./fer2013/train/sad/Training_6745845.jpg
#   inflating: ./fer2013/train/sad/Training_67467856.jpg
#   inflating: ./fer2013/train/sad/Training_67468920.jpg
#   inflating: ./fer2013/train/sad/Training_6748595.jpg
#   inflating: ./fer2013/train/sad/Training_67493222.jpg
#   inflating: ./fer2013/train/sad/Training_67528776.jpg
#   inflating: ./fer2013/train/sad/Training_67536310.jpg
#   inflating: ./fer2013/train/sad/Training_67556790.jpg
#   inflating: ./fer2013/train/sad/Training_67572813.jpg
#   inflating: ./fer2013/train/sad/Training_67591540.jpg
#   inflating: ./fer2013/train/sad/Training_67632832.jpg
#   inflating: ./fer2013/train/sad/Training_67669944.jpg
#   inflating: ./fer2013/train/sad/Training_67692740.jpg
#   inflating: ./fer2013/train/sad/Training_67708546.jpg
#   inflating: ./fer2013/train/sad/Training_67745215.jpg
#   inflating: ./fer2013/train/sad/Training_6777216.jpg
#   inflating: ./fer2013/train/sad/Training_67804138.jpg
#   inflating: ./fer2013/train/sad/Training_67813483.jpg
#   inflating: ./fer2013/train/sad/Training_67817866.jpg
#   inflating: ./fer2013/train/sad/Training_67818179.jpg
#   inflating: ./fer2013/train/sad/Training_67828892.jpg
#   inflating: ./fer2013/train/sad/Training_67837331.jpg
#   inflating: ./fer2013/train/sad/Training_67842276.jpg
#   inflating: ./fer2013/train/sad/Training_67850543.jpg
#   inflating: ./fer2013/train/sad/Training_67851920.jpg
#   inflating: ./fer2013/train/sad/Training_67882996.jpg
#   inflating: ./fer2013/train/sad/Training_67966108.jpg
#   inflating: ./fer2013/train/sad/Training_67985555.jpg
#   inflating: ./fer2013/train/sad/Training_68037479.jpg
#   inflating: ./fer2013/train/sad/Training_68045022.jpg
#   inflating: ./fer2013/train/sad/Training_68076888.jpg
#   inflating: ./fer2013/train/sad/Training_68089357.jpg
#   inflating: ./fer2013/train/sad/Training_68103747.jpg
#   inflating: ./fer2013/train/sad/Training_68128382.jpg
#   inflating: ./fer2013/train/sad/Training_68142058.jpg
#   inflating: ./fer2013/train/sad/Training_68159604.jpg
#   inflating: ./fer2013/train/sad/Training_68171793.jpg
#   inflating: ./fer2013/train/sad/Training_68200153.jpg
#   inflating: ./fer2013/train/sad/Training_68202501.jpg
#   inflating: ./fer2013/train/sad/Training_68244029.jpg
#   inflating: ./fer2013/train/sad/Training_68256652.jpg
#   inflating: ./fer2013/train/sad/Training_68280493.jpg
#   inflating: ./fer2013/train/sad/Training_68289103.jpg
#   inflating: ./fer2013/train/sad/Training_68290755.jpg
#   inflating: ./fer2013/train/sad/Training_6830318.jpg
#   inflating: ./fer2013/train/sad/Training_68307224.jpg
#   inflating: ./fer2013/train/sad/Training_68335728.jpg
#   inflating: ./fer2013/train/sad/Training_68370333.jpg
#   inflating: ./fer2013/train/sad/Training_68385314.jpg
#   inflating: ./fer2013/train/sad/Training_68408675.jpg
#   inflating: ./fer2013/train/sad/Training_6842792.jpg
#   inflating: ./fer2013/train/sad/Training_68430686.jpg
#   inflating: ./fer2013/train/sad/Training_68442333.jpg
#   inflating: ./fer2013/train/sad/Training_68473473.jpg
#   inflating: ./fer2013/train/sad/Training_68482325.jpg
#   inflating: ./fer2013/train/sad/Training_68484367.jpg
#   inflating: ./fer2013/train/sad/Training_68551663.jpg
#   inflating: ./fer2013/train/sad/Training_68571709.jpg
#   inflating: ./fer2013/train/sad/Training_68592359.jpg
#   inflating: ./fer2013/train/sad/Training_68595440.jpg
#   inflating: ./fer2013/train/sad/Training_68604461.jpg
#   inflating: ./fer2013/train/sad/Training_68638288.jpg
#   inflating: ./fer2013/train/sad/Training_68646641.jpg
#   inflating: ./fer2013/train/sad/Training_68688296.jpg
#   inflating: ./fer2013/train/sad/Training_68694648.jpg
#   inflating: ./fer2013/train/sad/Training_68710853.jpg
#   inflating: ./fer2013/train/sad/Training_68716255.jpg
#   inflating: ./fer2013/train/sad/Training_68738998.jpg
#   inflating: ./fer2013/train/sad/Training_68768411.jpg
#   inflating: ./fer2013/train/sad/Training_68779876.jpg
#   inflating: ./fer2013/train/sad/Training_68810853.jpg
#   inflating: ./fer2013/train/sad/Training_68836974.jpg
#   inflating: ./fer2013/train/sad/Training_68865659.jpg
#   inflating: ./fer2013/train/sad/Training_68875064.jpg
#   inflating: ./fer2013/train/sad/Training_68899646.jpg
#   inflating: ./fer2013/train/sad/Training_68936141.jpg
#   inflating: ./fer2013/train/sad/Training_69062237.jpg
#   inflating: ./fer2013/train/sad/Training_69151004.jpg
#   inflating: ./fer2013/train/sad/Training_69164072.jpg
#   inflating: ./fer2013/train/sad/Training_69206174.jpg
#   inflating: ./fer2013/train/sad/Training_69210256.jpg
#   inflating: ./fer2013/train/sad/Training_69241506.jpg
#   inflating: ./fer2013/train/sad/Training_69269398.jpg
#   inflating: ./fer2013/train/sad/Training_69291124.jpg
#   inflating: ./fer2013/train/sad/Training_6930508.jpg
#   inflating: ./fer2013/train/sad/Training_69334317.jpg
#   inflating: ./fer2013/train/sad/Training_69378971.jpg
#   inflating: ./fer2013/train/sad/Training_69382895.jpg
#   inflating: ./fer2013/train/sad/Training_69389790.jpg
#   inflating: ./fer2013/train/sad/Training_6939143.jpg
#   inflating: ./fer2013/train/sad/Training_69394388.jpg
#   inflating: ./fer2013/train/sad/Training_69395556.jpg
#   inflating: ./fer2013/train/sad/Training_69400238.jpg
#   inflating: ./fer2013/train/sad/Training_6947104.jpg
#   inflating: ./fer2013/train/sad/Training_6956023.jpg
#   inflating: ./fer2013/train/sad/Training_69563111.jpg
#   inflating: ./fer2013/train/sad/Training_69571000.jpg
#   inflating: ./fer2013/train/sad/Training_69615702.jpg
#   inflating: ./fer2013/train/sad/Training_69620341.jpg
#   inflating: ./fer2013/train/sad/Training_69633580.jpg
#   inflating: ./fer2013/train/sad/Training_69666372.jpg
#   inflating: ./fer2013/train/sad/Training_696816.jpg
#   inflating: ./fer2013/train/sad/Training_69690698.jpg
#   inflating: ./fer2013/train/sad/Training_69755939.jpg
#   inflating: ./fer2013/train/sad/Training_69757572.jpg
#   inflating: ./fer2013/train/sad/Training_69762456.jpg
#   inflating: ./fer2013/train/sad/Training_69763599.jpg
#   inflating: ./fer2013/train/sad/Training_69767645.jpg
#   inflating: ./fer2013/train/sad/Training_6977677.jpg
#   inflating: ./fer2013/train/sad/Training_69784078.jpg
#   inflating: ./fer2013/train/sad/Training_69814836.jpg
#   inflating: ./fer2013/train/sad/Training_69827762.jpg
#   inflating: ./fer2013/train/sad/Training_69845699.jpg
#   inflating: ./fer2013/train/sad/Training_69860257.jpg
#   inflating: ./fer2013/train/sad/Training_69861683.jpg
#   inflating: ./fer2013/train/sad/Training_69878041.jpg
#   inflating: ./fer2013/train/sad/Training_69897977.jpg
#   inflating: ./fer2013/train/sad/Training_69912786.jpg
#   inflating: ./fer2013/train/sad/Training_69919251.jpg
#   inflating: ./fer2013/train/sad/Training_69936046.jpg
#   inflating: ./fer2013/train/sad/Training_69939023.jpg
#   inflating: ./fer2013/train/sad/Training_69942887.jpg
#   inflating: ./fer2013/train/sad/Training_69945584.jpg
#   inflating: ./fer2013/train/sad/Training_69969238.jpg
#   inflating: ./fer2013/train/sad/Training_69982805.jpg
#   inflating: ./fer2013/train/sad/Training_6999681.jpg
#   inflating: ./fer2013/train/sad/Training_70035377.jpg
#   inflating: ./fer2013/train/sad/Training_70080960.jpg
#   inflating: ./fer2013/train/sad/Training_70091553.jpg
#   inflating: ./fer2013/train/sad/Training_70114086.jpg
#   inflating: ./fer2013/train/sad/Training_70161018.jpg
#   inflating: ./fer2013/train/sad/Training_70207644.jpg
#   inflating: ./fer2013/train/sad/Training_70229937.jpg
#   inflating: ./fer2013/train/sad/Training_70262923.jpg
#   inflating: ./fer2013/train/sad/Training_70266380.jpg
#   inflating: ./fer2013/train/sad/Training_70296904.jpg
#   inflating: ./fer2013/train/sad/Training_70297947.jpg
#   inflating: ./fer2013/train/sad/Training_70321234.jpg
#   inflating: ./fer2013/train/sad/Training_70378996.jpg
#   inflating: ./fer2013/train/sad/Training_70421844.jpg
#   inflating: ./fer2013/train/sad/Training_70436848.jpg
#   inflating: ./fer2013/train/sad/Training_7044634.jpg
#   inflating: ./fer2013/train/sad/Training_7045780.jpg
#   inflating: ./fer2013/train/sad/Training_70461378.jpg
#   inflating: ./fer2013/train/sad/Training_70521844.jpg
#   inflating: ./fer2013/train/sad/Training_70536939.jpg
#   inflating: ./fer2013/train/sad/Training_70583207.jpg
#   inflating: ./fer2013/train/sad/Training_70596208.jpg
#   inflating: ./fer2013/train/sad/Training_70599552.jpg
#   inflating: ./fer2013/train/sad/Training_70603263.jpg
#   inflating: ./fer2013/train/sad/Training_70607796.jpg
#   inflating: ./fer2013/train/sad/Training_70612607.jpg
#   inflating: ./fer2013/train/sad/Training_70634821.jpg
#   inflating: ./fer2013/train/sad/Training_706365.jpg
#   inflating: ./fer2013/train/sad/Training_70651275.jpg
#   inflating: ./fer2013/train/sad/Training_70662488.jpg
#   inflating: ./fer2013/train/sad/Training_70676169.jpg
#   inflating: ./fer2013/train/sad/Training_70678059.jpg
#   inflating: ./fer2013/train/sad/Training_70701274.jpg
#   inflating: ./fer2013/train/sad/Training_70718370.jpg
#   inflating: ./fer2013/train/sad/Training_70733870.jpg
#   inflating: ./fer2013/train/sad/Training_70769976.jpg
#   inflating: ./fer2013/train/sad/Training_70823629.jpg
#   inflating: ./fer2013/train/sad/Training_70934098.jpg
#   inflating: ./fer2013/train/sad/Training_70940444.jpg
#   inflating: ./fer2013/train/sad/Training_7095418.jpg
#   inflating: ./fer2013/train/sad/Training_70958370.jpg
#   inflating: ./fer2013/train/sad/Training_70958870.jpg
#   inflating: ./fer2013/train/sad/Training_70964123.jpg
#   inflating: ./fer2013/train/sad/Training_71007211.jpg
#   inflating: ./fer2013/train/sad/Training_71011588.jpg
#   inflating: ./fer2013/train/sad/Training_71037244.jpg
#   inflating: ./fer2013/train/sad/Training_71082937.jpg
#   inflating: ./fer2013/train/sad/Training_71115241.jpg
#   inflating: ./fer2013/train/sad/Training_71138337.jpg
#   inflating: ./fer2013/train/sad/Training_7117589.jpg
#   inflating: ./fer2013/train/sad/Training_71188788.jpg
#   inflating: ./fer2013/train/sad/Training_71196994.jpg
#   inflating: ./fer2013/train/sad/Training_71288773.jpg
#   inflating: ./fer2013/train/sad/Training_71288801.jpg
#   inflating: ./fer2013/train/sad/Training_71292002.jpg
#   inflating: ./fer2013/train/sad/Training_71292204.jpg
#   inflating: ./fer2013/train/sad/Training_71296493.jpg
#   inflating: ./fer2013/train/sad/Training_71310081.jpg
#   inflating: ./fer2013/train/sad/Training_71318950.jpg
#   inflating: ./fer2013/train/sad/Training_71334011.jpg
#   inflating: ./fer2013/train/sad/Training_71353503.jpg
#   inflating: ./fer2013/train/sad/Training_71419058.jpg
#   inflating: ./fer2013/train/sad/Training_71447345.jpg
#   inflating: ./fer2013/train/sad/Training_71451863.jpg
#   inflating: ./fer2013/train/sad/Training_71476978.jpg
#   inflating: ./fer2013/train/sad/Training_71488385.jpg
#   inflating: ./fer2013/train/sad/Training_71512023.jpg
#   inflating: ./fer2013/train/sad/Training_71527594.jpg
#   inflating: ./fer2013/train/sad/Training_71554470.jpg
#   inflating: ./fer2013/train/sad/Training_71570678.jpg
#   inflating: ./fer2013/train/sad/Training_71584150.jpg
#   inflating: ./fer2013/train/sad/Training_71584967.jpg
#   inflating: ./fer2013/train/sad/Training_71622452.jpg
#   inflating: ./fer2013/train/sad/Training_71627161.jpg
#   inflating: ./fer2013/train/sad/Training_7164832.jpg
#   inflating: ./fer2013/train/sad/Training_71649758.jpg
#   inflating: ./fer2013/train/sad/Training_71661069.jpg
#   inflating: ./fer2013/train/sad/Training_71669823.jpg
#   inflating: ./fer2013/train/sad/Training_7167918.jpg
#   inflating: ./fer2013/train/sad/Training_7170574.jpg
#   inflating: ./fer2013/train/sad/Training_71721961.jpg
#   inflating: ./fer2013/train/sad/Training_71776823.jpg
#   inflating: ./fer2013/train/sad/Training_71843157.jpg
#   inflating: ./fer2013/train/sad/Training_71883695.jpg
#   inflating: ./fer2013/train/sad/Training_71898080.jpg
#   inflating: ./fer2013/train/sad/Training_71898542.jpg
#   inflating: ./fer2013/train/sad/Training_71902821.jpg
#   inflating: ./fer2013/train/sad/Training_71934607.jpg
#   inflating: ./fer2013/train/sad/Training_71958451.jpg
#   inflating: ./fer2013/train/sad/Training_71976355.jpg
#   inflating: ./fer2013/train/sad/Training_71998111.jpg
#   inflating: ./fer2013/train/sad/Training_72047639.jpg
#   inflating: ./fer2013/train/sad/Training_72083858.jpg
#   inflating: ./fer2013/train/sad/Training_7209166.jpg
#   inflating: ./fer2013/train/sad/Training_72093577.jpg
#   inflating: ./fer2013/train/sad/Training_72099142.jpg
#   inflating: ./fer2013/train/sad/Training_72102844.jpg
#   inflating: ./fer2013/train/sad/Training_72110672.jpg
#   inflating: ./fer2013/train/sad/Training_72146177.jpg
#   inflating: ./fer2013/train/sad/Training_7215018.jpg
#   inflating: ./fer2013/train/sad/Training_72163737.jpg
#   inflating: ./fer2013/train/sad/Training_72173801.jpg
#   inflating: ./fer2013/train/sad/Training_72222596.jpg
#   inflating: ./fer2013/train/sad/Training_72224302.jpg
#   inflating: ./fer2013/train/sad/Training_72235014.jpg
#   inflating: ./fer2013/train/sad/Training_72253699.jpg
#   inflating: ./fer2013/train/sad/Training_72271772.jpg
#   inflating: ./fer2013/train/sad/Training_7228651.jpg
#   inflating: ./fer2013/train/sad/Training_72295557.jpg
#   inflating: ./fer2013/train/sad/Training_72325011.jpg
#   inflating: ./fer2013/train/sad/Training_72337521.jpg
#   inflating: ./fer2013/train/sad/Training_72338337.jpg
#   inflating: ./fer2013/train/sad/Training_72344183.jpg
#   inflating: ./fer2013/train/sad/Training_72346725.jpg
#   inflating: ./fer2013/train/sad/Training_72378190.jpg
#   inflating: ./fer2013/train/sad/Training_72389603.jpg
#   inflating: ./fer2013/train/sad/Training_72395127.jpg
#   inflating: ./fer2013/train/sad/Training_72399943.jpg
#   inflating: ./fer2013/train/sad/Training_72409954.jpg
#   inflating: ./fer2013/train/sad/Training_72460884.jpg
#   inflating: ./fer2013/train/sad/Training_72469576.jpg
#   inflating: ./fer2013/train/sad/Training_72496252.jpg
#   inflating: ./fer2013/train/sad/Training_72542126.jpg
#   inflating: ./fer2013/train/sad/Training_72569474.jpg
#   inflating: ./fer2013/train/sad/Training_72581485.jpg
#   inflating: ./fer2013/train/sad/Training_72591909.jpg
#   inflating: ./fer2013/train/sad/Training_72597782.jpg
#   inflating: ./fer2013/train/sad/Training_72611574.jpg
#   inflating: ./fer2013/train/sad/Training_72611844.jpg
#   inflating: ./fer2013/train/sad/Training_72615912.jpg
#   inflating: ./fer2013/train/sad/Training_72634633.jpg
#   inflating: ./fer2013/train/sad/Training_72643390.jpg
#   inflating: ./fer2013/train/sad/Training_72654049.jpg
#   inflating: ./fer2013/train/sad/Training_7269195.jpg
#   inflating: ./fer2013/train/sad/Training_72720479.jpg
#   inflating: ./fer2013/train/sad/Training_72723295.jpg
#   inflating: ./fer2013/train/sad/Training_7275452.jpg
#   inflating: ./fer2013/train/sad/Training_72762537.jpg
#   inflating: ./fer2013/train/sad/Training_72778292.jpg
#   inflating: ./fer2013/train/sad/Training_72783691.jpg
#   inflating: ./fer2013/train/sad/Training_72811320.jpg
#   inflating: ./fer2013/train/sad/Training_72840504.jpg
#   inflating: ./fer2013/train/sad/Training_72841025.jpg
#   inflating: ./fer2013/train/sad/Training_72863073.jpg
#   inflating: ./fer2013/train/sad/Training_72896318.jpg
#   inflating: ./fer2013/train/sad/Training_72903645.jpg
#   inflating: ./fer2013/train/sad/Training_7298615.jpg
#   inflating: ./fer2013/train/sad/Training_73008225.jpg
#   inflating: ./fer2013/train/sad/Training_73009287.jpg
#   inflating: ./fer2013/train/sad/Training_73009503.jpg
#   inflating: ./fer2013/train/sad/Training_73037101.jpg
#   inflating: ./fer2013/train/sad/Training_73046118.jpg
#   inflating: ./fer2013/train/sad/Training_73057152.jpg
#   inflating: ./fer2013/train/sad/Training_73057687.jpg
#   inflating: ./fer2013/train/sad/Training_73058352.jpg
#   inflating: ./fer2013/train/sad/Training_73075893.jpg
#   inflating: ./fer2013/train/sad/Training_73092569.jpg
#   inflating: ./fer2013/train/sad/Training_73106861.jpg
#   inflating: ./fer2013/train/sad/Training_73109136.jpg
#   inflating: ./fer2013/train/sad/Training_73157275.jpg
#   inflating: ./fer2013/train/sad/Training_73179474.jpg
#   inflating: ./fer2013/train/sad/Training_73180212.jpg
#   inflating: ./fer2013/train/sad/Training_73180906.jpg
#   inflating: ./fer2013/train/sad/Training_73192317.jpg
#   inflating: ./fer2013/train/sad/Training_73207709.jpg
#   inflating: ./fer2013/train/sad/Training_73215932.jpg
#   inflating: ./fer2013/train/sad/Training_73221082.jpg
#   inflating: ./fer2013/train/sad/Training_73221224.jpg
#   inflating: ./fer2013/train/sad/Training_73230439.jpg
#   inflating: ./fer2013/train/sad/Training_73353739.jpg
#   inflating: ./fer2013/train/sad/Training_73359813.jpg
#   inflating: ./fer2013/train/sad/Training_73361195.jpg
#   inflating: ./fer2013/train/sad/Training_73374075.jpg
#   inflating: ./fer2013/train/sad/Training_73381526.jpg
#   inflating: ./fer2013/train/sad/Training_7338492.jpg
#   inflating: ./fer2013/train/sad/Training_73393003.jpg
#   inflating: ./fer2013/train/sad/Training_73408195.jpg
#   inflating: ./fer2013/train/sad/Training_73440556.jpg
#   inflating: ./fer2013/train/sad/Training_73491794.jpg
#   inflating: ./fer2013/train/sad/Training_73514241.jpg
#   inflating: ./fer2013/train/sad/Training_73517508.jpg
#   inflating: ./fer2013/train/sad/Training_73530752.jpg
#   inflating: ./fer2013/train/sad/Training_73535020.jpg
#   inflating: ./fer2013/train/sad/Training_73550785.jpg
#   inflating: ./fer2013/train/sad/Training_73563278.jpg
#   inflating: ./fer2013/train/sad/Training_73569064.jpg
#   inflating: ./fer2013/train/sad/Training_73593223.jpg
#   inflating: ./fer2013/train/sad/Training_7360259.jpg
#   inflating: ./fer2013/train/sad/Training_73619612.jpg
#   inflating: ./fer2013/train/sad/Training_73677468.jpg
#   inflating: ./fer2013/train/sad/Training_7368170.jpg
#   inflating: ./fer2013/train/sad/Training_7368650.jpg
#   inflating: ./fer2013/train/sad/Training_73704673.jpg
#   inflating: ./fer2013/train/sad/Training_73743414.jpg
#   inflating: ./fer2013/train/sad/Training_73768093.jpg
#   inflating: ./fer2013/train/sad/Training_73771138.jpg
#   inflating: ./fer2013/train/sad/Training_73806297.jpg
#   inflating: ./fer2013/train/sad/Training_73814276.jpg
#   inflating: ./fer2013/train/sad/Training_73815301.jpg
#   inflating: ./fer2013/train/sad/Training_73821059.jpg
#   inflating: ./fer2013/train/sad/Training_73825583.jpg
#   inflating: ./fer2013/train/sad/Training_73841476.jpg
#   inflating: ./fer2013/train/sad/Training_73846262.jpg
#   inflating: ./fer2013/train/sad/Training_73882625.jpg
#   inflating: ./fer2013/train/sad/Training_73884877.jpg
#   inflating: ./fer2013/train/sad/Training_73899462.jpg
#   inflating: ./fer2013/train/sad/Training_73913636.jpg
#   inflating: ./fer2013/train/sad/Training_73922667.jpg
#   inflating: ./fer2013/train/sad/Training_73928625.jpg
#   inflating: ./fer2013/train/sad/Training_73954004.jpg
#   inflating: ./fer2013/train/sad/Training_73972027.jpg
#   inflating: ./fer2013/train/sad/Training_73991927.jpg
#   inflating: ./fer2013/train/sad/Training_73996544.jpg
#   inflating: ./fer2013/train/sad/Training_7401108.jpg
#   inflating: ./fer2013/train/sad/Training_74023330.jpg
#   inflating: ./fer2013/train/sad/Training_74033981.jpg
#   inflating: ./fer2013/train/sad/Training_74065266.jpg
#   inflating: ./fer2013/train/sad/Training_74072045.jpg
#   inflating: ./fer2013/train/sad/Training_74080914.jpg
#   inflating: ./fer2013/train/sad/Training_74093072.jpg
#   inflating: ./fer2013/train/sad/Training_74101198.jpg
#   inflating: ./fer2013/train/sad/Training_74105412.jpg
#   inflating: ./fer2013/train/sad/Training_7410773.jpg
#   inflating: ./fer2013/train/sad/Training_74136066.jpg
#   inflating: ./fer2013/train/sad/Training_74136619.jpg
#   inflating: ./fer2013/train/sad/Training_74152534.jpg
#   inflating: ./fer2013/train/sad/Training_7415406.jpg
#   inflating: ./fer2013/train/sad/Training_7421898.jpg
#   inflating: ./fer2013/train/sad/Training_74279721.jpg
#   inflating: ./fer2013/train/sad/Training_74299759.jpg
#   inflating: ./fer2013/train/sad/Training_74350756.jpg
#   inflating: ./fer2013/train/sad/Training_74358544.jpg
#   inflating: ./fer2013/train/sad/Training_74368010.jpg
#   inflating: ./fer2013/train/sad/Training_74411661.jpg
#   inflating: ./fer2013/train/sad/Training_74414713.jpg
#   inflating: ./fer2013/train/sad/Training_74435111.jpg
#   inflating: ./fer2013/train/sad/Training_74470648.jpg
#   inflating: ./fer2013/train/sad/Training_74502717.jpg
#   inflating: ./fer2013/train/sad/Training_74568768.jpg
#   inflating: ./fer2013/train/sad/Training_74573435.jpg
#   inflating: ./fer2013/train/sad/Training_74579668.jpg
#   inflating: ./fer2013/train/sad/Training_74600155.jpg
#   inflating: ./fer2013/train/sad/Training_74603491.jpg
#   inflating: ./fer2013/train/sad/Training_74630860.jpg
#   inflating: ./fer2013/train/sad/Training_74647082.jpg
#   inflating: ./fer2013/train/sad/Training_74660658.jpg
#   inflating: ./fer2013/train/sad/Training_74663426.jpg
#   inflating: ./fer2013/train/sad/Training_74719415.jpg
#   inflating: ./fer2013/train/sad/Training_74729984.jpg
#   inflating: ./fer2013/train/sad/Training_74752869.jpg
#   inflating: ./fer2013/train/sad/Training_74779597.jpg
#   inflating: ./fer2013/train/sad/Training_74788956.jpg
#   inflating: ./fer2013/train/sad/Training_74803271.jpg
#   inflating: ./fer2013/train/sad/Training_74806656.jpg
#   inflating: ./fer2013/train/sad/Training_74832345.jpg
#   inflating: ./fer2013/train/sad/Training_74835832.jpg
#   inflating: ./fer2013/train/sad/Training_74837191.jpg
#   inflating: ./fer2013/train/sad/Training_74869127.jpg
#   inflating: ./fer2013/train/sad/Training_7492201.jpg
#   inflating: ./fer2013/train/sad/Training_74923508.jpg
#   inflating: ./fer2013/train/sad/Training_74935742.jpg
#   inflating: ./fer2013/train/sad/Training_74959363.jpg
#   inflating: ./fer2013/train/sad/Training_74965466.jpg
#   inflating: ./fer2013/train/sad/Training_74983244.jpg
#   inflating: ./fer2013/train/sad/Training_74994333.jpg
#   inflating: ./fer2013/train/sad/Training_74998300.jpg
#   inflating: ./fer2013/train/sad/Training_75008092.jpg
#   inflating: ./fer2013/train/sad/Training_75034927.jpg
#   inflating: ./fer2013/train/sad/Training_75067659.jpg
#   inflating: ./fer2013/train/sad/Training_75082078.jpg
#   inflating: ./fer2013/train/sad/Training_75083073.jpg
#   inflating: ./fer2013/train/sad/Training_75110513.jpg
#   inflating: ./fer2013/train/sad/Training_7513470.jpg
#   inflating: ./fer2013/train/sad/Training_75135222.jpg
#   inflating: ./fer2013/train/sad/Training_75159666.jpg
#   inflating: ./fer2013/train/sad/Training_75170083.jpg
#   inflating: ./fer2013/train/sad/Training_75171465.jpg
#   inflating: ./fer2013/train/sad/Training_75189928.jpg
#   inflating: ./fer2013/train/sad/Training_75214583.jpg
#   inflating: ./fer2013/train/sad/Training_7525300.jpg
#   inflating: ./fer2013/train/sad/Training_75262711.jpg
#   inflating: ./fer2013/train/sad/Training_75262873.jpg
#   inflating: ./fer2013/train/sad/Training_75274984.jpg
#   inflating: ./fer2013/train/sad/Training_75293540.jpg
#   inflating: ./fer2013/train/sad/Training_75313915.jpg
#   inflating: ./fer2013/train/sad/Training_75341606.jpg
#   inflating: ./fer2013/train/sad/Training_75350741.jpg
#   inflating: ./fer2013/train/sad/Training_75356262.jpg
#   inflating: ./fer2013/train/sad/Training_75368167.jpg
#   inflating: ./fer2013/train/sad/Training_75387198.jpg
#   inflating: ./fer2013/train/sad/Training_75410725.jpg
#   inflating: ./fer2013/train/sad/Training_75416581.jpg
#   inflating: ./fer2013/train/sad/Training_75416938.jpg
#   inflating: ./fer2013/train/sad/Training_75444602.jpg
#   inflating: ./fer2013/train/sad/Training_7549724.jpg
#   inflating: ./fer2013/train/sad/Training_75543640.jpg
#   inflating: ./fer2013/train/sad/Training_75543932.jpg
#   inflating: ./fer2013/train/sad/Training_75571535.jpg
#   inflating: ./fer2013/train/sad/Training_75610438.jpg
#   inflating: ./fer2013/train/sad/Training_75611272.jpg
#   inflating: ./fer2013/train/sad/Training_75618319.jpg
#   inflating: ./fer2013/train/sad/Training_75621135.jpg
#   inflating: ./fer2013/train/sad/Training_75624853.jpg
#   inflating: ./fer2013/train/sad/Training_75635467.jpg
#   inflating: ./fer2013/train/sad/Training_75646677.jpg
#   inflating: ./fer2013/train/sad/Training_75660322.jpg
#   inflating: ./fer2013/train/sad/Training_75700227.jpg
#   inflating: ./fer2013/train/sad/Training_75707572.jpg
#   inflating: ./fer2013/train/sad/Training_75719873.jpg
#   inflating: ./fer2013/train/sad/Training_75724813.jpg
#   inflating: ./fer2013/train/sad/Training_75727403.jpg
#   inflating: ./fer2013/train/sad/Training_75766217.jpg
#   inflating: ./fer2013/train/sad/Training_75787895.jpg
#   inflating: ./fer2013/train/sad/Training_75799681.jpg
#   inflating: ./fer2013/train/sad/Training_75848425.jpg
#   inflating: ./fer2013/train/sad/Training_75874059.jpg
#   inflating: ./fer2013/train/sad/Training_7587826.jpg
#   inflating: ./fer2013/train/sad/Training_75911539.jpg
#   inflating: ./fer2013/train/sad/Training_75913936.jpg
#   inflating: ./fer2013/train/sad/Training_75937447.jpg
#   inflating: ./fer2013/train/sad/Training_75981229.jpg
#   inflating: ./fer2013/train/sad/Training_75989216.jpg
#   inflating: ./fer2013/train/sad/Training_76033714.jpg
#   inflating: ./fer2013/train/sad/Training_76054912.jpg
#   inflating: ./fer2013/train/sad/Training_76072526.jpg
#   inflating: ./fer2013/train/sad/Training_76078228.jpg
#   inflating: ./fer2013/train/sad/Training_76093170.jpg
#   inflating: ./fer2013/train/sad/Training_76156703.jpg
#   inflating: ./fer2013/train/sad/Training_76172020.jpg
#   inflating: ./fer2013/train/sad/Training_76242403.jpg
#   inflating: ./fer2013/train/sad/Training_76247539.jpg
#   inflating: ./fer2013/train/sad/Training_76337396.jpg
#   inflating: ./fer2013/train/sad/Training_76350973.jpg
#   inflating: ./fer2013/train/sad/Training_76359569.jpg
#   inflating: ./fer2013/train/sad/Training_76420897.jpg
#   inflating: ./fer2013/train/sad/Training_76430810.jpg
#   inflating: ./fer2013/train/sad/Training_76476336.jpg
#   inflating: ./fer2013/train/sad/Training_76520571.jpg
#   inflating: ./fer2013/train/sad/Training_76521474.jpg
#   inflating: ./fer2013/train/sad/Training_76527846.jpg
#   inflating: ./fer2013/train/sad/Training_76572193.jpg
#   inflating: ./fer2013/train/sad/Training_765835.jpg
#   inflating: ./fer2013/train/sad/Training_76596885.jpg
#   inflating: ./fer2013/train/sad/Training_76640624.jpg
#   inflating: ./fer2013/train/sad/Training_76656854.jpg
#   inflating: ./fer2013/train/sad/Training_76673414.jpg
#   inflating: ./fer2013/train/sad/Training_76689888.jpg
#   inflating: ./fer2013/train/sad/Training_76693132.jpg
#   inflating: ./fer2013/train/sad/Training_76733432.jpg
#   inflating: ./fer2013/train/sad/Training_76753108.jpg
#   inflating: ./fer2013/train/sad/Training_76762566.jpg
#   inflating: ./fer2013/train/sad/Training_76775461.jpg
#   inflating: ./fer2013/train/sad/Training_76784987.jpg
#   inflating: ./fer2013/train/sad/Training_76791590.jpg
#   inflating: ./fer2013/train/sad/Training_76838629.jpg
#   inflating: ./fer2013/train/sad/Training_76873410.jpg
#   inflating: ./fer2013/train/sad/Training_76875172.jpg
#   inflating: ./fer2013/train/sad/Training_7688937.jpg
#   inflating: ./fer2013/train/sad/Training_76985291.jpg
#   inflating: ./fer2013/train/sad/Training_77016343.jpg
#   inflating: ./fer2013/train/sad/Training_77028632.jpg
#   inflating: ./fer2013/train/sad/Training_77047483.jpg
#   inflating: ./fer2013/train/sad/Training_77050371.jpg
#   inflating: ./fer2013/train/sad/Training_7705182.jpg
#   inflating: ./fer2013/train/sad/Training_77054367.jpg
#   inflating: ./fer2013/train/sad/Training_77080138.jpg
#   inflating: ./fer2013/train/sad/Training_7708402.jpg
#   inflating: ./fer2013/train/sad/Training_77113075.jpg
#   inflating: ./fer2013/train/sad/Training_77117966.jpg
#   inflating: ./fer2013/train/sad/Training_7711966.jpg
#   inflating: ./fer2013/train/sad/Training_771314.jpg
#   inflating: ./fer2013/train/sad/Training_77151653.jpg
#   inflating: ./fer2013/train/sad/Training_77158311.jpg
#   inflating: ./fer2013/train/sad/Training_77160993.jpg
#   inflating: ./fer2013/train/sad/Training_7718130.jpg
#   inflating: ./fer2013/train/sad/Training_77240805.jpg
#   inflating: ./fer2013/train/sad/Training_77313526.jpg
#   inflating: ./fer2013/train/sad/Training_77318703.jpg
#   inflating: ./fer2013/train/sad/Training_77332384.jpg
#   inflating: ./fer2013/train/sad/Training_77355699.jpg
#   inflating: ./fer2013/train/sad/Training_77361751.jpg
#   inflating: ./fer2013/train/sad/Training_77374373.jpg
#   inflating: ./fer2013/train/sad/Training_77375068.jpg
#   inflating: ./fer2013/train/sad/Training_77385699.jpg
#   inflating: ./fer2013/train/sad/Training_77394585.jpg
#   inflating: ./fer2013/train/sad/Training_77397756.jpg
#   inflating: ./fer2013/train/sad/Training_77411040.jpg
#   inflating: ./fer2013/train/sad/Training_77427125.jpg
#   inflating: ./fer2013/train/sad/Training_77502812.jpg
#   inflating: ./fer2013/train/sad/Training_77535999.jpg
#   inflating: ./fer2013/train/sad/Training_77538613.jpg
#   inflating: ./fer2013/train/sad/Training_77561478.jpg
#   inflating: ./fer2013/train/sad/Training_77592896.jpg
#   inflating: ./fer2013/train/sad/Training_77595440.jpg
#   inflating: ./fer2013/train/sad/Training_77621186.jpg
#   inflating: ./fer2013/train/sad/Training_77692339.jpg
#   inflating: ./fer2013/train/sad/Training_77708150.jpg
#   inflating: ./fer2013/train/sad/Training_77718583.jpg
#   inflating: ./fer2013/train/sad/Training_7776501.jpg
#   inflating: ./fer2013/train/sad/Training_77800976.jpg
#   inflating: ./fer2013/train/sad/Training_77824660.jpg
#   inflating: ./fer2013/train/sad/Training_77825744.jpg
#   inflating: ./fer2013/train/sad/Training_77846583.jpg
#   inflating: ./fer2013/train/sad/Training_77853230.jpg
#   inflating: ./fer2013/train/sad/Training_77866797.jpg
#   inflating: ./fer2013/train/sad/Training_77901137.jpg
#   inflating: ./fer2013/train/sad/Training_77907745.jpg
#   inflating: ./fer2013/train/sad/Training_7791103.jpg
#   inflating: ./fer2013/train/sad/Training_77919469.jpg
#   inflating: ./fer2013/train/sad/Training_77927007.jpg
#   inflating: ./fer2013/train/sad/Training_77938374.jpg
#   inflating: ./fer2013/train/sad/Training_77978390.jpg
#   inflating: ./fer2013/train/sad/Training_77992570.jpg
#   inflating: ./fer2013/train/sad/Training_77994782.jpg
#   inflating: ./fer2013/train/sad/Training_78060020.jpg
#   inflating: ./fer2013/train/sad/Training_78077558.jpg
#   inflating: ./fer2013/train/sad/Training_78106696.jpg
#   inflating: ./fer2013/train/sad/Training_78109009.jpg
#   inflating: ./fer2013/train/sad/Training_7811127.jpg
#   inflating: ./fer2013/train/sad/Training_78115403.jpg
#   inflating: ./fer2013/train/sad/Training_78130963.jpg
#   inflating: ./fer2013/train/sad/Training_78142280.jpg
#   inflating: ./fer2013/train/sad/Training_7816570.jpg
#   inflating: ./fer2013/train/sad/Training_78178750.jpg
#   inflating: ./fer2013/train/sad/Training_78191339.jpg
#   inflating: ./fer2013/train/sad/Training_78222724.jpg
#   inflating: ./fer2013/train/sad/Training_78226550.jpg
#   inflating: ./fer2013/train/sad/Training_78236652.jpg
#   inflating: ./fer2013/train/sad/Training_78244666.jpg
#   inflating: ./fer2013/train/sad/Training_78252572.jpg
#   inflating: ./fer2013/train/sad/Training_78259953.jpg
#   inflating: ./fer2013/train/sad/Training_78263773.jpg
#   inflating: ./fer2013/train/sad/Training_78280823.jpg
#   inflating: ./fer2013/train/sad/Training_78282619.jpg
#   inflating: ./fer2013/train/sad/Training_78304061.jpg
#   inflating: ./fer2013/train/sad/Training_78306602.jpg
#   inflating: ./fer2013/train/sad/Training_78310916.jpg
#   inflating: ./fer2013/train/sad/Training_78314397.jpg
#   inflating: ./fer2013/train/sad/Training_78323726.jpg
#   inflating: ./fer2013/train/sad/Training_78338992.jpg
#   inflating: ./fer2013/train/sad/Training_78363728.jpg
#   inflating: ./fer2013/train/sad/Training_78373088.jpg
#   inflating: ./fer2013/train/sad/Training_78374290.jpg
#   inflating: ./fer2013/train/sad/Training_78391775.jpg
#   inflating: ./fer2013/train/sad/Training_78444257.jpg
#   inflating: ./fer2013/train/sad/Training_78500318.jpg
#   inflating: ./fer2013/train/sad/Training_78512361.jpg
#   inflating: ./fer2013/train/sad/Training_78533904.jpg
#   inflating: ./fer2013/train/sad/Training_78537346.jpg
#   inflating: ./fer2013/train/sad/Training_78580473.jpg
#   inflating: ./fer2013/train/sad/Training_78637258.jpg
#   inflating: ./fer2013/train/sad/Training_78658686.jpg
#   inflating: ./fer2013/train/sad/Training_78698675.jpg
#   inflating: ./fer2013/train/sad/Training_78711005.jpg
#   inflating: ./fer2013/train/sad/Training_78713328.jpg
#   inflating: ./fer2013/train/sad/Training_78714614.jpg
#   inflating: ./fer2013/train/sad/Training_78744933.jpg
#   inflating: ./fer2013/train/sad/Training_78746497.jpg
#   inflating: ./fer2013/train/sad/Training_78771425.jpg
#   inflating: ./fer2013/train/sad/Training_78793953.jpg
#   inflating: ./fer2013/train/sad/Training_78798891.jpg
#   inflating: ./fer2013/train/sad/Training_78808789.jpg
#   inflating: ./fer2013/train/sad/Training_78818631.jpg
#   inflating: ./fer2013/train/sad/Training_78822832.jpg
#   inflating: ./fer2013/train/sad/Training_78842185.jpg
#   inflating: ./fer2013/train/sad/Training_78850836.jpg
#   inflating: ./fer2013/train/sad/Training_7885587.jpg
#   inflating: ./fer2013/train/sad/Training_78975310.jpg
#   inflating: ./fer2013/train/sad/Training_78985679.jpg
#   inflating: ./fer2013/train/sad/Training_78986879.jpg
#   inflating: ./fer2013/train/sad/Training_79032308.jpg
#   inflating: ./fer2013/train/sad/Training_79051384.jpg
#   inflating: ./fer2013/train/sad/Training_79061910.jpg
#   inflating: ./fer2013/train/sad/Training_79070746.jpg
#   inflating: ./fer2013/train/sad/Training_79079382.jpg
#   inflating: ./fer2013/train/sad/Training_79107437.jpg
#   inflating: ./fer2013/train/sad/Training_79108628.jpg
#   inflating: ./fer2013/train/sad/Training_79122693.jpg
#   inflating: ./fer2013/train/sad/Training_79140066.jpg
#   inflating: ./fer2013/train/sad/Training_79168469.jpg
#   inflating: ./fer2013/train/sad/Training_79170275.jpg
#   inflating: ./fer2013/train/sad/Training_79173226.jpg
#   inflating: ./fer2013/train/sad/Training_79185737.jpg
#   inflating: ./fer2013/train/sad/Training_7920978.jpg
#   inflating: ./fer2013/train/sad/Training_79234860.jpg
#   inflating: ./fer2013/train/sad/Training_79244828.jpg
#   inflating: ./fer2013/train/sad/Training_79258455.jpg
#   inflating: ./fer2013/train/sad/Training_79289652.jpg
#   inflating: ./fer2013/train/sad/Training_79345073.jpg
#   inflating: ./fer2013/train/sad/Training_79347036.jpg
#   inflating: ./fer2013/train/sad/Training_79348405.jpg
#   inflating: ./fer2013/train/sad/Training_79349140.jpg
#   inflating: ./fer2013/train/sad/Training_79376728.jpg
#   inflating: ./fer2013/train/sad/Training_79382417.jpg
#   inflating: ./fer2013/train/sad/Training_79397869.jpg
#   inflating: ./fer2013/train/sad/Training_79402229.jpg
#   inflating: ./fer2013/train/sad/Training_79422885.jpg
#   inflating: ./fer2013/train/sad/Training_79441584.jpg
#   inflating: ./fer2013/train/sad/Training_79446524.jpg
#   inflating: ./fer2013/train/sad/Training_79467007.jpg
#   inflating: ./fer2013/train/sad/Training_79471335.jpg
#   inflating: ./fer2013/train/sad/Training_79471378.jpg
#   inflating: ./fer2013/train/sad/Training_7958960.jpg
#   inflating: ./fer2013/train/sad/Training_79596916.jpg
#   inflating: ./fer2013/train/sad/Training_79598993.jpg
#   inflating: ./fer2013/train/sad/Training_79606094.jpg
#   inflating: ./fer2013/train/sad/Training_79680889.jpg
#   inflating: ./fer2013/train/sad/Training_79713448.jpg
#   inflating: ./fer2013/train/sad/Training_79726354.jpg
#   inflating: ./fer2013/train/sad/Training_79736851.jpg
#   inflating: ./fer2013/train/sad/Training_79741353.jpg
#   inflating: ./fer2013/train/sad/Training_79758901.jpg
#   inflating: ./fer2013/train/sad/Training_79776909.jpg
#   inflating: ./fer2013/train/sad/Training_79786488.jpg
#   inflating: ./fer2013/train/sad/Training_7979691.jpg
#   inflating: ./fer2013/train/sad/Training_79807922.jpg
#   inflating: ./fer2013/train/sad/Training_79815522.jpg
#   inflating: ./fer2013/train/sad/Training_79843120.jpg
#   inflating: ./fer2013/train/sad/Training_79860018.jpg
#   inflating: ./fer2013/train/sad/Training_79896402.jpg
#   inflating: ./fer2013/train/sad/Training_7991765.jpg
#   inflating: ./fer2013/train/sad/Training_79931718.jpg
#   inflating: ./fer2013/train/sad/Training_79948141.jpg
#   inflating: ./fer2013/train/sad/Training_79950523.jpg
#   inflating: ./fer2013/train/sad/Training_80017807.jpg
#   inflating: ./fer2013/train/sad/Training_80026827.jpg
#   inflating: ./fer2013/train/sad/Training_80030764.jpg
#   inflating: ./fer2013/train/sad/Training_8006911.jpg
#   inflating: ./fer2013/train/sad/Training_80112431.jpg
#   inflating: ./fer2013/train/sad/Training_80116947.jpg
#   inflating: ./fer2013/train/sad/Training_80125846.jpg
#   inflating: ./fer2013/train/sad/Training_80130045.jpg
#   inflating: ./fer2013/train/sad/Training_80184735.jpg
#   inflating: ./fer2013/train/sad/Training_80195598.jpg
#   inflating: ./fer2013/train/sad/Training_80204177.jpg
#   inflating: ./fer2013/train/sad/Training_80274936.jpg
#   inflating: ./fer2013/train/sad/Training_80331424.jpg
#   inflating: ./fer2013/train/sad/Training_80338672.jpg
#   inflating: ./fer2013/train/sad/Training_80348614.jpg
#   inflating: ./fer2013/train/sad/Training_80385070.jpg
#   inflating: ./fer2013/train/sad/Training_8039829.jpg
#   inflating: ./fer2013/train/sad/Training_8041120.jpg
#   inflating: ./fer2013/train/sad/Training_80441506.jpg
#   inflating: ./fer2013/train/sad/Training_8044159.jpg
#   inflating: ./fer2013/train/sad/Training_8044739.jpg
#   inflating: ./fer2013/train/sad/Training_80459486.jpg
#   inflating: ./fer2013/train/sad/Training_80481807.jpg
#   inflating: ./fer2013/train/sad/Training_80487839.jpg
#   inflating: ./fer2013/train/sad/Training_80488173.jpg
#   inflating: ./fer2013/train/sad/Training_80494891.jpg
#   inflating: ./fer2013/train/sad/Training_80537785.jpg
#   inflating: ./fer2013/train/sad/Training_80579424.jpg
#   inflating: ./fer2013/train/sad/Training_80661655.jpg
#   inflating: ./fer2013/train/sad/Training_80695070.jpg
#   inflating: ./fer2013/train/sad/Training_80695781.jpg
#   inflating: ./fer2013/train/sad/Training_80704106.jpg
#   inflating: ./fer2013/train/sad/Training_80719498.jpg
#   inflating: ./fer2013/train/sad/Training_80719524.jpg
#   inflating: ./fer2013/train/sad/Training_80738105.jpg
#   inflating: ./fer2013/train/sad/Training_80738472.jpg
#   inflating: ./fer2013/train/sad/Training_80765087.jpg
#   inflating: ./fer2013/train/sad/Training_80774004.jpg
#   inflating: ./fer2013/train/sad/Training_80777074.jpg
#   inflating: ./fer2013/train/sad/Training_80803992.jpg
#   inflating: ./fer2013/train/sad/Training_80819471.jpg
#   inflating: ./fer2013/train/sad/Training_8083052.jpg
#   inflating: ./fer2013/train/sad/Training_80876097.jpg
#   inflating: ./fer2013/train/sad/Training_80881769.jpg
#   inflating: ./fer2013/train/sad/Training_80881868.jpg
#   inflating: ./fer2013/train/sad/Training_80890988.jpg
#   inflating: ./fer2013/train/sad/Training_80899611.jpg
#   inflating: ./fer2013/train/sad/Training_80949693.jpg
#   inflating: ./fer2013/train/sad/Training_8096703.jpg
#   inflating: ./fer2013/train/sad/Training_80971452.jpg
#   inflating: ./fer2013/train/sad/Training_80974723.jpg
#   inflating: ./fer2013/train/sad/Training_80981346.jpg
#   inflating: ./fer2013/train/sad/Training_81008287.jpg
#   inflating: ./fer2013/train/sad/Training_81013514.jpg
#   inflating: ./fer2013/train/sad/Training_81039583.jpg
#   inflating: ./fer2013/train/sad/Training_81048535.jpg
#   inflating: ./fer2013/train/sad/Training_81053420.jpg
#   inflating: ./fer2013/train/sad/Training_81075199.jpg
#   inflating: ./fer2013/train/sad/Training_81097657.jpg
#   inflating: ./fer2013/train/sad/Training_81101893.jpg
# ...
#   inflating: ./fer2013/train/surprise/Training_92209603.jpg
#   inflating: ./fer2013/train/surprise/Training_9224814.jpg
#   inflating: ./fer2013/train/surprise/Training_92248829.jpg
#   inflating: ./fer2013/train/surprise/Training_92274884.jpg
#   inflating: ./fer2013/train/surprise/Training_92312755.jpg
#   inflating: ./fer2013/train/surprise/Training_92354298.jpg
#   inflating: ./fer2013/train/surprise/Training_92408940.jpg
#   inflating: ./fer2013/train/surprise/Training_92423948.jpg
#   inflating: ./fer2013/train/surprise/Training_9243945.jpg
#   inflating: ./fer2013/train/surprise/Training_92479434.jpg
#   inflating: ./fer2013/train/surprise/Training_92516152.jpg
#   inflating: ./fer2013/train/surprise/Training_92532325.jpg
#   inflating: ./fer2013/train/surprise/Training_92587887.jpg
#   inflating: ./fer2013/train/surprise/Training_92595345.jpg
#   inflating: ./fer2013/train/surprise/Training_92606057.jpg
#   inflating: ./fer2013/train/surprise/Training_92608034.jpg
#   inflating: ./fer2013/train/surprise/Training_92638202.jpg
#   inflating: ./fer2013/train/surprise/Training_9263983.jpg
#   inflating: ./fer2013/train/surprise/Training_92652268.jpg
#   inflating: ./fer2013/train/surprise/Training_92666649.jpg
#   inflating: ./fer2013/train/surprise/Training_92701859.jpg
#   inflating: ./fer2013/train/surprise/Training_92768155.jpg
#   inflating: ./fer2013/train/surprise/Training_9278243.jpg
#   inflating: ./fer2013/train/surprise/Training_92846416.jpg
#   inflating: ./fer2013/train/surprise/Training_92923337.jpg
#   inflating: ./fer2013/train/surprise/Training_92984568.jpg
#   inflating: ./fer2013/train/surprise/Training_93006194.jpg
#   inflating: ./fer2013/train/surprise/Training_93037336.jpg
#   inflating: ./fer2013/train/surprise/Training_93055491.jpg
#   inflating: ./fer2013/train/surprise/Training_93101746.jpg
#   inflating: ./fer2013/train/surprise/Training_93122504.jpg
#   inflating: ./fer2013/train/surprise/Training_93172846.jpg
#   inflating: ./fer2013/train/surprise/Training_93342559.jpg
#   inflating: ./fer2013/train/surprise/Training_9340355.jpg
#   inflating: ./fer2013/train/surprise/Training_93417164.jpg
#   inflating: ./fer2013/train/surprise/Training_9342491.jpg
#   inflating: ./fer2013/train/surprise/Training_93442446.jpg
#   inflating: ./fer2013/train/surprise/Training_93443959.jpg
#   inflating: ./fer2013/train/surprise/Training_93474212.jpg
#   inflating: ./fer2013/train/surprise/Training_93492148.jpg
#   inflating: ./fer2013/train/surprise/Training_93560263.jpg
#   inflating: ./fer2013/train/surprise/Training_93625113.jpg
#   inflating: ./fer2013/train/surprise/Training_93625752.jpg
#   inflating: ./fer2013/train/surprise/Training_93642020.jpg
#   inflating: ./fer2013/train/surprise/Training_93658821.jpg
#   inflating: ./fer2013/train/surprise/Training_93675722.jpg
#   inflating: ./fer2013/train/surprise/Training_93699149.jpg
#   inflating: ./fer2013/train/surprise/Training_93713521.jpg
#   inflating: ./fer2013/train/surprise/Training_93735232.jpg
#   inflating: ./fer2013/train/surprise/Training_93742686.jpg
#   inflating: ./fer2013/train/surprise/Training_93744466.jpg
#   inflating: ./fer2013/train/surprise/Training_93747086.jpg
#   inflating: ./fer2013/train/surprise/Training_93918990.jpg
#   inflating: ./fer2013/train/surprise/Training_93922116.jpg
#   inflating: ./fer2013/train/surprise/Training_93942694.jpg
#   inflating: ./fer2013/train/surprise/Training_93944440.jpg
#   inflating: ./fer2013/train/surprise/Training_93981745.jpg
#   inflating: ./fer2013/train/surprise/Training_93997972.jpg
#   inflating: ./fer2013/train/surprise/Training_94014854.jpg
#   inflating: ./fer2013/train/surprise/Training_94108784.jpg
#   inflating: ./fer2013/train/surprise/Training_941343.jpg
#   inflating: ./fer2013/train/surprise/Training_94164371.jpg
#   inflating: ./fer2013/train/surprise/Training_9419936.jpg
#   inflating: ./fer2013/train/surprise/Training_94220119.jpg
#   inflating: ./fer2013/train/surprise/Training_94234220.jpg
#   inflating: ./fer2013/train/surprise/Training_94244032.jpg
#   inflating: ./fer2013/train/surprise/Training_94259743.jpg
#   inflating: ./fer2013/train/surprise/Training_9426774.jpg
#   inflating: ./fer2013/train/surprise/Training_9428441.jpg
#   inflating: ./fer2013/train/surprise/Training_94303347.jpg
#   inflating: ./fer2013/train/surprise/Training_94363754.jpg
#   inflating: ./fer2013/train/surprise/Training_94470519.jpg
#   inflating: ./fer2013/train/surprise/Training_94535865.jpg
#   inflating: ./fer2013/train/surprise/Training_94582829.jpg
#   inflating: ./fer2013/train/surprise/Training_94607952.jpg
#   inflating: ./fer2013/train/surprise/Training_94690773.jpg
#   inflating: ./fer2013/train/surprise/Training_94690831.jpg
#   inflating: ./fer2013/train/surprise/Training_94760289.jpg
#   inflating: ./fer2013/train/surprise/Training_94804140.jpg
#   inflating: ./fer2013/train/surprise/Training_94815054.jpg
#   inflating: ./fer2013/train/surprise/Training_94859807.jpg
#   inflating: ./fer2013/train/surprise/Training_94871392.jpg
#   inflating: ./fer2013/train/surprise/Training_94872292.jpg
#   inflating: ./fer2013/train/surprise/Training_94885610.jpg
#   inflating: ./fer2013/train/surprise/Training_94916496.jpg
#   inflating: ./fer2013/train/surprise/Training_94931391.jpg
#   inflating: ./fer2013/train/surprise/Training_95007623.jpg
#   inflating: ./fer2013/train/surprise/Training_95045198.jpg
#   inflating: ./fer2013/train/surprise/Training_95079686.jpg
#   inflating: ./fer2013/train/surprise/Training_95101558.jpg
#   inflating: ./fer2013/train/surprise/Training_95163599.jpg
#   inflating: ./fer2013/train/surprise/Training_95187678.jpg
#   inflating: ./fer2013/train/surprise/Training_95204802.jpg
#   inflating: ./fer2013/train/surprise/Training_95232145.jpg
#   inflating: ./fer2013/train/surprise/Training_95310908.jpg
#   inflating: ./fer2013/train/surprise/Training_95325414.jpg
#   inflating: ./fer2013/train/surprise/Training_95402552.jpg
#   inflating: ./fer2013/train/surprise/Training_95451817.jpg
#   inflating: ./fer2013/train/surprise/Training_95461460.jpg
#   inflating: ./fer2013/train/surprise/Training_95495690.jpg
#   inflating: ./fer2013/train/surprise/Training_95558533.jpg
#   inflating: ./fer2013/train/surprise/Training_95600814.jpg
#   inflating: ./fer2013/train/surprise/Training_95689131.jpg
#   inflating: ./fer2013/train/surprise/Training_95699837.jpg
#   inflating: ./fer2013/train/surprise/Training_95706228.jpg
#   inflating: ./fer2013/train/surprise/Training_95708850.jpg
#   inflating: ./fer2013/train/surprise/Training_95755746.jpg
#   inflating: ./fer2013/train/surprise/Training_95773470.jpg
#   inflating: ./fer2013/train/surprise/Training_95805741.jpg
#   inflating: ./fer2013/train/surprise/Training_95830400.jpg
#   inflating: ./fer2013/train/surprise/Training_95847480.jpg
#   inflating: ./fer2013/train/surprise/Training_95853103.jpg
#   inflating: ./fer2013/train/surprise/Training_95880970.jpg
#   inflating: ./fer2013/train/surprise/Training_95966009.jpg
#   inflating: ./fer2013/train/surprise/Training_95988339.jpg
#   inflating: ./fer2013/train/surprise/Training_95989089.jpg
#   inflating: ./fer2013/train/surprise/Training_9602572.jpg
#   inflating: ./fer2013/train/surprise/Training_96163000.jpg
#   inflating: ./fer2013/train/surprise/Training_96163370.jpg
#   inflating: ./fer2013/train/surprise/Training_96193805.jpg
#   inflating: ./fer2013/train/surprise/Training_96202596.jpg
#   inflating: ./fer2013/train/surprise/Training_96210289.jpg
#   inflating: ./fer2013/train/surprise/Training_96238543.jpg
#   inflating: ./fer2013/train/surprise/Training_96277880.jpg
#   inflating: ./fer2013/train/surprise/Training_96287206.jpg
#   inflating: ./fer2013/train/surprise/Training_96389125.jpg
#   inflating: ./fer2013/train/surprise/Training_96389792.jpg
#   inflating: ./fer2013/train/surprise/Training_96446762.jpg
#   inflating: ./fer2013/train/surprise/Training_96475488.jpg
#   inflating: ./fer2013/train/surprise/Training_96533198.jpg
#   inflating: ./fer2013/train/surprise/Training_96572434.jpg
#   inflating: ./fer2013/train/surprise/Training_96596500.jpg
#   inflating: ./fer2013/train/surprise/Training_96642531.jpg
#   inflating: ./fer2013/train/surprise/Training_96656714.jpg
#   inflating: ./fer2013/train/surprise/Training_96661519.jpg
#   inflating: ./fer2013/train/surprise/Training_96670821.jpg
#   inflating: ./fer2013/train/surprise/Training_96672701.jpg
#   inflating: ./fer2013/train/surprise/Training_96695026.jpg
#   inflating: ./fer2013/train/surprise/Training_96734839.jpg
#   inflating: ./fer2013/train/surprise/Training_9676011.jpg
#   inflating: ./fer2013/train/surprise/Training_96765324.jpg
#   inflating: ./fer2013/train/surprise/Training_96765430.jpg
#   inflating: ./fer2013/train/surprise/Training_96800478.jpg
#   inflating: ./fer2013/train/surprise/Training_96848455.jpg
#   inflating: ./fer2013/train/surprise/Training_96914394.jpg
#   inflating: ./fer2013/train/surprise/Training_96970066.jpg
#   inflating: ./fer2013/train/surprise/Training_97062924.jpg
#   inflating: ./fer2013/train/surprise/Training_97090047.jpg
#   inflating: ./fer2013/train/surprise/Training_97100020.jpg
#   inflating: ./fer2013/train/surprise/Training_97109955.jpg
#   inflating: ./fer2013/train/surprise/Training_97149632.jpg
#   inflating: ./fer2013/train/surprise/Training_97209154.jpg
#   inflating: ./fer2013/train/surprise/Training_97275390.jpg
#   inflating: ./fer2013/train/surprise/Training_97284057.jpg
#   inflating: ./fer2013/train/surprise/Training_97313556.jpg
#   inflating: ./fer2013/train/surprise/Training_97372586.jpg
#   inflating: ./fer2013/train/surprise/Training_97386553.jpg
#   inflating: ./fer2013/train/surprise/Training_97424717.jpg
#   inflating: ./fer2013/train/surprise/Training_97427205.jpg
#   inflating: ./fer2013/train/surprise/Training_97427552.jpg
#   inflating: ./fer2013/train/surprise/Training_97440583.jpg
#   inflating: ./fer2013/train/surprise/Training_97444585.jpg
#   inflating: ./fer2013/train/surprise/Training_97615083.jpg
#   inflating: ./fer2013/train/surprise/Training_97658524.jpg
#   inflating: ./fer2013/train/surprise/Training_97667504.jpg
#   inflating: ./fer2013/train/surprise/Training_97675828.jpg
#   inflating: ./fer2013/train/surprise/Training_976799.jpg
#   inflating: ./fer2013/train/surprise/Training_97705054.jpg
#   inflating: ./fer2013/train/surprise/Training_97834691.jpg
#   inflating: ./fer2013/train/surprise/Training_97847754.jpg
#   inflating: ./fer2013/train/surprise/Training_97872221.jpg
#   inflating: ./fer2013/train/surprise/Training_97913254.jpg
#   inflating: ./fer2013/train/surprise/Training_97921487.jpg
#   inflating: ./fer2013/train/surprise/Training_97921838.jpg
#   inflating: ./fer2013/train/surprise/Training_9796387.jpg
#   inflating: ./fer2013/train/surprise/Training_98011942.jpg
#   inflating: ./fer2013/train/surprise/Training_98062605.jpg
#   inflating: ./fer2013/train/surprise/Training_98067546.jpg
#   inflating: ./fer2013/train/surprise/Training_98069171.jpg
#   inflating: ./fer2013/train/surprise/Training_98079493.jpg
#   inflating: ./fer2013/train/surprise/Training_98084340.jpg
#   inflating: ./fer2013/train/surprise/Training_98137653.jpg
#   inflating: ./fer2013/train/surprise/Training_98160615.jpg
#   inflating: ./fer2013/train/surprise/Training_98169661.jpg
#   inflating: ./fer2013/train/surprise/Training_98192978.jpg
#   inflating: ./fer2013/train/surprise/Training_98197769.jpg
#   inflating: ./fer2013/train/surprise/Training_98223737.jpg
#   inflating: ./fer2013/train/surprise/Training_98223779.jpg
#   inflating: ./fer2013/train/surprise/Training_98234175.jpg
#   inflating: ./fer2013/train/surprise/Training_98235103.jpg
#   inflating: ./fer2013/train/surprise/Training_98241018.jpg
#   inflating: ./fer2013/train/surprise/Training_98315142.jpg
#   inflating: ./fer2013/train/surprise/Training_98334836.jpg
#   inflating: ./fer2013/train/surprise/Training_98349673.jpg
#   inflating: ./fer2013/train/surprise/Training_98352897.jpg
#   inflating: ./fer2013/train/surprise/Training_98381187.jpg
#   inflating: ./fer2013/train/surprise/Training_9839279.jpg
#   inflating: ./fer2013/train/surprise/Training_98393554.jpg
#   inflating: ./fer2013/train/surprise/Training_98397319.jpg
#   inflating: ./fer2013/train/surprise/Training_98409862.jpg
#   inflating: ./fer2013/train/surprise/Training_98446939.jpg
#   inflating: ./fer2013/train/surprise/Training_98447563.jpg
#   inflating: ./fer2013/train/surprise/Training_98472640.jpg
#   inflating: ./fer2013/train/surprise/Training_98481914.jpg
#   inflating: ./fer2013/train/surprise/Training_98511054.jpg
#   inflating: ./fer2013/train/surprise/Training_98514521.jpg
#   inflating: ./fer2013/train/surprise/Training_98539906.jpg
#   inflating: ./fer2013/train/surprise/Training_98569897.jpg
#   inflating: ./fer2013/train/surprise/Training_98576352.jpg
#   inflating: ./fer2013/train/surprise/Training_98588726.jpg
#   inflating: ./fer2013/train/surprise/Training_98594534.jpg
#   inflating: ./fer2013/train/surprise/Training_98644924.jpg
#   inflating: ./fer2013/train/surprise/Training_98657632.jpg
#   inflating: ./fer2013/train/surprise/Training_98664620.jpg
#   inflating: ./fer2013/train/surprise/Training_98737557.jpg
#   inflating: ./fer2013/train/surprise/Training_98747340.jpg
#   inflating: ./fer2013/train/surprise/Training_98750930.jpg
#   inflating: ./fer2013/train/surprise/Training_98758885.jpg
#   inflating: ./fer2013/train/surprise/Training_98767792.jpg
#   inflating: ./fer2013/train/surprise/Training_98774734.jpg
#   inflating: ./fer2013/train/surprise/Training_9880069.jpg
#   inflating: ./fer2013/train/surprise/Training_98827007.jpg
#   inflating: ./fer2013/train/surprise/Training_98828949.jpg
#   inflating: ./fer2013/train/surprise/Training_98840937.jpg
#   inflating: ./fer2013/train/surprise/Training_98861159.jpg
#   inflating: ./fer2013/train/surprise/Training_98899707.jpg
#   inflating: ./fer2013/train/surprise/Training_9890261.jpg
#   inflating: ./fer2013/train/surprise/Training_98971238.jpg
#   inflating: ./fer2013/train/surprise/Training_98972491.jpg
#   inflating: ./fer2013/train/surprise/Training_99066709.jpg
#   inflating: ./fer2013/train/surprise/Training_9909756.jpg
#   inflating: ./fer2013/train/surprise/Training_99104204.jpg
#   inflating: ./fer2013/train/surprise/Training_99106305.jpg
#   inflating: ./fer2013/train/surprise/Training_99113691.jpg
#   inflating: ./fer2013/train/surprise/Training_991508.jpg
#   inflating: ./fer2013/train/surprise/Training_99182527.jpg
#   inflating: ./fer2013/train/surprise/Training_99233432.jpg
#   inflating: ./fer2013/train/surprise/Training_99267647.jpg
#   inflating: ./fer2013/train/surprise/Training_99279802.jpg
#   inflating: ./fer2013/train/surprise/Training_99318660.jpg
#   inflating: ./fer2013/train/surprise/Training_9932811.jpg
#   inflating: ./fer2013/train/surprise/Training_99399304.jpg
#   inflating: ./fer2013/train/surprise/Training_99399823.jpg
#   inflating: ./fer2013/train/surprise/Training_99404349.jpg
#   inflating: ./fer2013/train/surprise/Training_9943398.jpg
#   inflating: ./fer2013/train/surprise/Training_99441101.jpg
#   inflating: ./fer2013/train/surprise/Training_99576616.jpg
#   inflating: ./fer2013/train/surprise/Training_99604118.jpg
#   inflating: ./fer2013/train/surprise/Training_99663019.jpg
#   inflating: ./fer2013/train/surprise/Training_99791966.jpg
#   inflating: ./fer2013/train/surprise/Training_99794165.jpg
#   inflating: ./fer2013/train/surprise/Training_99807705.jpg
#   inflating: ./fer2013/train/surprise/Training_99827442.jpg
#   inflating: ./fer2013/train/surprise/Training_99916297.jpg
#   inflating: ./fer2013/train/surprise/Training_99924420.jpg
#   inflating: ./fer2013/train/surprise/Training_99937001.jpg
#   inflating: ./fer2013/train/surprise/Training_99951755.jpg
#   inflating: ./fer2013/train/surprise/Training_99984132.jpg

# %% [markdown]
# ### 방법2) 구글 드라이브 마운트하여 가져온 후 압축파일 해제하기

# %%
from google.colab import drive       # ... 코드입력
drive.mount('/content/drive')        # ... 코드입력
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-79a83fc31717> in <cell line: 2>()
#       1 from google.colab import drive       # ... 코드입력
# ----> 2 drive.mount('/content/drive')        # ... 코드입력
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     135     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import zipfile

# zipfile.ZipFile() 사용하여 fer2013 하위폴더에 압축풀기
path = /content/drive/MyDrive/Colab Notebooks/2024 Intel Edge AI SW academy/0508-09    # ... 코드입력
zip_object = os.path.join(path, "archive.zip")    # ... 코드입력

# fer2013 하위폴더에 압축풀기
...    # ... 코드입력
# close()하기
...    # ... 코드입력

# %% [markdown]
# ## 방법3 ) Kaggele 사이트에서 직접 다운로드하기

# %%
# colab - linux
# !pip install kaggle

# %%
mkdir ~/.kaggle

# %% [markdown]
# - kaggle 사이트의 My Profile > settings > API 에서 'create New Token' => 'kaggle.son' 다운로드해서 colab으로 upload 하기

# %%
! cp kaggle.json ~/.kaggle/

# %% [markdown]
# - https://www.kaggle.com/datasets/msambare/fer2013 의 우상단 설정에서 'Copy Api command' 클릭하기

# %%
# 데이터셋 다운로드 kaggle의 api command 사용하여 다운로드하기
! kaggle datasets download -d msambare/fer2013

# %%
# 압축풀기
...    # ... 코드입력

# %% [markdown]
# - 이미지 확인해보기

# %%
import tensorflow as tf
import numpy as np

tf.keras.preprocessing.image.load_img('/content/fer-2013/train/happy/Training_10019449.jpg')

# %%
tf.keras.preprocessing.image.load_img('/content/fer-2013/train/surprise/Training_10013223.jpg')

# %%
img = tf.keras.preprocessing.image.load_img('/content/fer-2013/train/neutral/Training_10002154.jpg')
np.array(img).shape

# %%
np.array(img).shape[1], np.array(img).shape[0]

# %% [markdown]
# ## 2. 학습/테스트 데이터셋 생성하기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_generator = ImageDataGenerator(rotation_range=10,  # 이미지를 무작위로 회전시킬 최대 각도
                                     zoom_range=0.2,  # 이미지를 무작위로 확대/축소할 범위를 지정,1 - 0.2 = 0.8배에서 1 + 0.2 = 1.2배 사이의 무작위 스케일로 이미지를 확대 또는 축소
                                     horizontal_flip=True,  # 이미지를 수평 방향(좌우)으로 무작위로 뒤집기
                                     rescale=1/255)  # 이미지의 픽셀 값을 0에서 255의 범위에서 0에서 1의 범위로 정규화

# %% [markdown]
# - `ImageDataGenerator()`는 실시간 데이터 증대를 통해 텐서 이미지 데이터 배치를 생성합니다. (참고: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator)
#   - `rotation_range`, `zoom_range`, `horizontal_flip`은 데이터 증대를 위한 매개변수입니다.
#   - `rescale`은 정규화를 위한 매개변수입니다.

# %%
train_dataset = train_generator.flow_from_directory(directory='/content/fer2013/train',
                                                    target_size=(48, 48),  # 로드된 이미지의 크기를 조정할 대상의 크기, defaults to (256, 256)
                                                    class_mode='categorical', # one-hot 인코딩된 레이블을 반환, 다중 클래스 분류 문제 적합
                                                    batch_size=16,  # 한 번에 네트워크로 전달될 이미지의 수 (default: 32)
                                                    shuffle=True,  # 에포크마다 데이터를 섞을지 여부를 결정 (default: True) If set to False, sorts the data in alphanumeric order
                                                    seed=10)

# %% [markdown]
# -  ImageDataGenerator를 활용하여 디렉토리로부터 훈련 데이터를 로드하고, 데이터 증강을 적용한 데이터셋을 생성하는 과정 설정
# - flow_from_directory 메서드는 지정된 디렉토리 구조 내의 이미지 파일들을 읽어서, 데이터 증강을 적용한 후 훈련 데이터로 사용할 수 있는 배치(batch) 형태로 제공

# %%
dir(train_dataset)

# %%
train_dataset.classes

# %%
train_dataset.class_indices

# %%
import numpy as np

np.unique(train_dataset.classes, return_counts=True)

# %% [markdown]
# - Disgust에 해당하는 436개의 이미지는 상대적으로 작습니다.

# %%
test_generator = ImageDataGenerator(rescale=1/255)

test_dataset = test_generator.flow_from_directory(directory='/content/fer2013/test',
                                                  target_size=(48, 48),
                                                  class_mode='categorical',
                                                  batch_size=1,
                                                  shuffle=False,
                                                  seed=10)

# %% [markdown]
# - 테스트 과정에서 데이터의 원본 상태를 유지하면서 모델 평가의 일관성과 신뢰성을 보장하기위해 증강 적용하지 않
# - `batch_size=1`인 이유는 하나씩 테스트해 볼 예정이기 때문입니다.

# %% [markdown]
# ## 3. 모델 구성하기 (Convolutional Neural Network,CNN)

# %% [markdown]
# 다음 모델 구성을 보고 코드를 작성하세요
# ```
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        896
#
#  batch_normalization (Batch  (None, 48, 48, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 48, 48, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 24, 24, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        36928
#
#  batch_normalization_3 (Bat  (None, 24, 24, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  batch_normalization_4 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#  ```

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization

num_classes = 7                        # len(train_dataset.class_indices)
num_detectors = 32
width, height = 48, 48                 #  np.array(img).shape[1], np.array(img).shape[0]

model = Sequential()

model.add(Conv2D(filters=num_detectors, kernel_size=3, activation='relu', padding='same', input_shape=(width, height, 3)))
model.add(BatchNormalization())
model.add(Conv2D(filters=num_detectors, kernel_size=3, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters=num_detectors*2, kernel_size=3, activation='relu', padding='same', input_shape=(width, height, 3)))
model.add(BatchNormalization())
model.add(Conv2D(filters=num_detectors*2, kernel_size=3, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(2*2*num_detectors, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(2*num_detectors))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(num_classes))

# %%
print(model.summary())

# %%
# 모델 컴파일하기 : optimizer - 'Adam'
import tensorflow as tf

model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# ## 4. 모델 학습하기

# %%
epochs = 20

model.fit(train_dataset, epochs=epochs)
# Out:
# Epoch 1/20
# 1795/1795 [==============================] - 76s 30ms/step - loss: 6.5341 - accuracy: 0.1078
# Epoch 2/20
# 1795/1795 [==============================] - 56s 31ms/step - loss: 7.7823 - accuracy: 0.1298
# Epoch 3/20
# 1795/1795 [==============================] - 53s 29ms/step - loss: 7.9367 - accuracy: 0.1257
# Epoch 4/20
# 1795/1795 [==============================] - 51s 29ms/step - loss: 7.6412 - accuracy: 0.1234
# Epoch 5/20
# 1795/1795 [==============================] - 51s 28ms/step - loss: 8.1583 - accuracy: 0.1308
# Epoch 6/20
# 1795/1795 [==============================] - 51s 28ms/step - loss: 7.8152 - accuracy: 0.1305
# Epoch 7/20
# 1795/1795 [==============================] - 53s 29ms/step - loss: 7.9514 - accuracy: 0.1343
# Epoch 8/20
# 1795/1795 [==============================] - 51s 29ms/step - loss: 7.2889 - accuracy: 0.1365
# Epoch 9/20
# 1795/1795 [==============================] - 49s 27ms/step - loss: 8.2670 - accuracy: 0.1211
# Epoch 10/20
# 1795/1795 [==============================] - 50s 28ms/step - loss: 8.4919 - accuracy: 0.1509
# Epoch 11/20
# 1795/1795 [==============================] - 50s 28ms/step - loss: 7.9608 - accuracy: 0.1645
# Epoch 12/20
# 1795/1795 [==============================] - 52s 29ms/step - loss: 7.7874 - accuracy: 0.1371
# Epoch 13/20
# 1795/1795 [==============================] - 47s 26ms/step - loss: 8.6343 - accuracy: 0.1210
# Epoch 14/20
# 1795/1795 [==============================] - 48s 27ms/step - loss: 7.9524 - accuracy: 0.1210
# Epoch 15/20
# 1795/1795 [==============================] - 50s 28ms/step - loss: 7.6149 - accuracy: 0.1317
# Epoch 16/20
# 1795/1795 [==============================] - 47s 26ms/step - loss: 8.0374 - accuracy: 0.1330
# Epoch 17/20
# 1795/1795 [==============================] - 50s 28ms/step - loss: 7.9402 - accuracy: 0.1347
# Epoch 18/20
# 1795/1795 [==============================] - 50s 28ms/step - loss: 8.4439 - accuracy: 0.1330
# Epoch 19/20
# 1795/1795 [==============================] - 46s 25ms/step - loss: 7.8548 - accuracy: 0.1367
# Epoch 20/20
# 1795/1795 [==============================] - 47s 26ms/step - loss: 8.5237 - accuracy: 0.1426

# %% [markdown]
# ## 5. 모델 평가하기

# %%
score = model.evaluate(test_dataset)    # ... 코드입력

print(f'accuracy : {round(score[1],2)}, loss : {round(score[0],2)}')
# Out:
# 7178/7178 [==============================] - 26s 4ms/step - loss: 9.9722 - accuracy: 0.1436
# accuracy : 0.14, loss : 9.97

# %%
preds = model.predict(test_dataset)    # ... 코드입력
preds

# %%
preds = np.argmax(preds, axis=1)
preds
# Out:
# array([4, 4, 3, ..., 1, 4, 1])

# %%
test_dataset.classes

# %%
import pandas as pd

df_result = pd.DataFrame(columns=['Actual', 'Predicted'])
df_result['Actual'] = test_dataset.classes
df_result['Predicted'] = preds
df_result
# Out:
#       Actual  Predicted
# 0          0          4
# 1          0          4
# 2          0          3
# 3          0          3
# 4          0          4
# ...      ...        ...
# 7173       6          1
# 7174       6          1
# 7175       6          1
# 7176       6          4
# 7177       6          1
#
# [7178 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

accuracy_score(test_dataset.classes, preds)
# Out:
# 0.14363332404569518

# %%
test_dataset.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# 시각화할 이미지 개수
import matplotlib.pyplot as plt
num_images = 5
samples_to_display = np.random.choice(len(test_dataset), num_images, replace=False)

# 테스트 데이터 중 일부 이미지 시각화
for i, idx in enumerate(samples_to_display):
    img, label = test_dataset[idx]  # 이미지와 레이블을 가져옵니다
    img = img[0]  # 배치 차원 제거
    true_label = test_dataset.classes[idx]
    pred_label = preds[idx]
    plt.figure(figsize=(5, 3))
    plt.imshow(img)
    plt.title(f"True: {true_label}, Pred: {pred_label}")
    plt.axis('off')
    plt.show()

# %%
# 시각화할 이미지 개수
num_images = 5
#samples_to_display = np.random.choice(len(test_dataset), num_images, replace=False)
samples_to_display = np.random.choice(test_dataset.n, num_images, replace=False)

# # 테스트 데이터 중 일부 이미지 시각화
# for i, idx in enumerate(samples_to_display):
#     img = test_dataset[idx].squeeze()  # 차원 축소
#     true_label = y_test_classes[idx]
#     pred_label = preds_classes[idx]
#     plt.figure(figsize=(5, 3))
#     plt.imshow(img, cmap='gray')
#     plt.title(f"True: {test_dataset.class_indices[true_label]}, Pred: {test_dataset.class_indices[pred_label]}")
#     plt.axis('off')
#     plt.show()

# 테스트 데이터 중 일부 이미지 시각화
for i, idx in enumerate(samples_to_display):
    # 데이터셋에서 이미지를 추출하려면, idx를 배치 인덱스와 위치 인덱스로 변환해야 합니다.
    batch_index = idx // test_dataset.batch_size
    img_index = idx % test_dataset.batch_size
    # 데이터 제너레이터에서 배치를 로드합니다.
    img_batch, label_batch = test_dataset[batch_index]
    img = img_batch[img_index].squeeze()  # 차원 축소
    true_label = np.argmax(label_batch[img_index])
    pred_label = preds[idx]

    plt.figure(figsize=(5, 3))
    plt.imshow(img, cmap='gray')
    # 클래스 인덱스를 클래스 이름으로 변환하여 표시합니다.
    plt.title(f"True: {list(test_dataset.class_indices.keys())[true_label]}, Pred: {list(test_dataset.class_indices.keys())[pred_label]}")
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## 6. 모델 저장하고 로드하기

# %% [markdown]
# - 모델/가중치를 저장하고 로드하려면 아래 코드의 주석 처리를 취소하고 사용하 세요.

# %%
from keras.models import save_model

# 모델 전체를 'model.h5' 파일로 저장
save_model(model, 'model.h5')

# 모델의 구조를 JSON 문자열로 반환-모델을 구성하는 각 레이어의 구성과 설정이 포함
with open('trained_model.json', 'w') as trained_model_json:
    trained_model_json.write(model.to_json())

# 모델 구조 로드하기
with open('trained_model.json', 'r') as trained_model_json:
    trained_model_json = trained_model_json.read()

# 모델 가중치 저장하기
save_model(model, '/content/weights_emotions.hdf5')

# Load the trained model & weights
model = tf.keras.models.model_from_json(trained_model_json)
model.load_weights('/content/weights_emotions.hdf5')
# Out:
# <ipython-input-24-277f41891192>:4: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(model, 'model.h5')
# <ipython-input-24-277f41891192>:15: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(model, '/content/weights_emotions.hdf5')

# %% [markdown]
# ## 7. 실제 이미지로 분류하기 - 사전 학습된 모델 사용

# %%
# 테스트할 이미지 파일 다운로드하기
# !gdown 1YT-S4qnWprl2Nd6GdDsfI5S-Fot9jEXl
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1YT-S4qnWprl2Nd6GdDsfI5S-Fot9jEXl
# To: /content/happy_face.jpg
# 100% 138k/138k [00:00<00:00, 97.8MB/s]

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('happy_face.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x1280>

# %% [markdown]
# ### **`mmod_human_face_detector.dat`** : Dlib 라이브러리에서 사용되는, 얼굴 인식을 위한 딥러닝 모델 파일
# - Dlib은 컴퓨터 비전과 머신 러닝을 위한 C++ 라이브러리이며, Python 바인딩을 통해 Python에서도 사용할 수 있습니다.
# - `mmod_human_face_detector.dat` 파일은 특히 Dlib의 최대 마진 객체 감지(Max-Margin Object Detection, MMOD) 알고리즘을 사용한 인간 얼굴 감지 모델을 포함하고 있습니다.
# - https://github.com/justadudewhohacks/face-recognition.js-models/blob/master/models/mmod_human_face_detector.dat
#
# - MMOD는 딥러닝 기반의 객체 감지 알고리즘 중 하나로, 각 객체에 대해 손실 함수를 최소화하는 방식으로 동작합니다. 이 알고리즘은 특히 작은 데이터 세트에서도 높은 성능을 낼 수 있도록 설계되었으며, 객체 감지 모델을 학습시킬 때 사용됩니다. MMOD는 객체 감지 문제를 학습 문제로 변환하여, 특정 객체(여기서는 인간의 얼굴)를 이미지에서 정확하게 찾아내도록 합니다.
#
# `mmod_human_face_detector.dat` 파일은 Dlib 라이브러리를 사용하여 얼굴 감지 기능을 구현할 때 필요한 사전 학습된 모델이며, 특정 어플리케이션에 적용하여 얼굴 감지 기능을 신속하게 구현할 수 있도록 해줍니다.

# %%
# 사전 훈련된 모델 다운로드하기 - mmod_human_face_detector.dat
# !gdown 1nRnLt6Y2p85sudWohdGYPsLWHa6vryF9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1nRnLt6Y2p85sudWohdGYPsLWHa6vryF9
# To: /content/mmod_human_face_detector.dat
# 100% 730k/730k [00:00<00:00, 93.9MB/s]

# %%
import dlib
face_detector = dlib.cnn_face_detection_model_v1('mmod_human_face_detector.dat')

face_detection = face_detector(image, 1)
face_detection
# Out:
# mmod_rectangles[[(426, 491) (849, 913)]]

# %%
left, top, right, bottom = face_detection[0].rect.left(), face_detection[0].rect.top(), face_detection[0].rect.right(), face_detection[0].rect.bottom()

roi = image[top:bottom, left:right]

cv2_imshow(roi)

# %%
roi.shape

# %%
# Resize image - 학습데이터와 사이즈 맞추기
roi = cv2.resize(roi, (48, 48))

roi.shape
# Out:
# (48, 48, 3)

# %%
# Normalize
roi = roi / 255

# %%
# CNN 모델은 4차원 배열로 변환하여 모델에 입력해야하므로 차원 변경
roi = np.expand_dims(roi, axis=0)   # axis=0은 배열의 가장 앞에 차원을 추가
roi.shape
# Out:
# (1, 48, 48, 3)

# %%
pred_probability = model.predict(roi)
pred_probability
# Out:
# 1/1 [==============================] - 0s 173ms/step
# array([[  7.768589  , -12.977239  ,   0.13897868,   9.286182  ,
#           1.3416178 ,   3.5770187 ,  -9.548366  ]], dtype=float32)

# %%
pred = np.argmax(pred_probability)
pred
# Out:
# 3

# %% [markdown]
# # **이미지 증강방식 사용 안하는 방식**

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt

# 데이터셋 디렉토리 경로 설정
dataset_directory = '/content/fer-2013'

# 클래스 이름 및 데이터 로딩
class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
image_data = []
labels = []

for class_name in class_names:
    class_folder = os.path.join(dataset_directory, 'train', class_name)
    for image_name in os.listdir(class_folder):
        image_path = os.path.join(class_folder, image_name)
        image = cv2.imread(image_path)  # 그레이스케일로 읽기
        image = cv2.resize(image, (48, 48))  # 이미지 크기 조정
        image_data.append(image)
        labels.append(class_names.index(class_name))

# 데이터를 NumPy 배열로 변환 및 레이블 One-Hot 인코딩
image_data = np.array(image_data)
image_data = np.expand_dims(image_data, axis=-1)  # Conv2D에 맞게 차원 확장
labels = to_categorical(labels, num_classes=len(class_names))

# %%
#모델 구성 및 컴파일 (이전과 동일)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization

num_classes = 7
num_detectors = 32
width, height = 48, 48

model2 = Sequential()

model2.add(Conv2D(filters=num_detectors, kernel_size=3, activation='relu', padding='same', input_shape=(width, height, 3)))
model2.add(BatchNormalization())
model2.add(Conv2D(filters=num_detectors, kernel_size=3, activation='relu', padding='same'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.2))

model2.add(Conv2D(2*num_detectors, 3, activation='relu', padding='same'))
model2.add(BatchNormalization())
model2.add(Conv2D(2*num_detectors, 3, activation='relu', padding='same'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.2))

model2.add(Conv2D(2*2*num_detectors, 3, activation='relu', padding='same'))
model2.add(BatchNormalization())
model2.add(Conv2D(2*2*num_detectors, 3, activation='relu', padding='same'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.2))

model2.add(Flatten())

model2.add(Dense(2*2*num_detectors, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.2))

model2.add(Dense(2*num_detectors, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.2))

model2.add(Dense(num_classes, activation='softmax'))

model2.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

#모델 학습
epochs = 10
model2.fit(image_data, labels, epochs=epochs)
# Out:
# Epoch 1/10
# 898/898 [==============================] - 20s 15ms/step - loss: 1.7606 - accuracy: 0.3331
# Epoch 2/10
# 898/898 [==============================] - 13s 15ms/step - loss: 1.3747 - accuracy: 0.4740
# Epoch 3/10
# 898/898 [==============================] - 17s 19ms/step - loss: 1.2561 - accuracy: 0.5203
# Epoch 4/10
# 898/898 [==============================] - 14s 16ms/step - loss: 1.1868 - accuracy: 0.5517
# Epoch 5/10
# 898/898 [==============================] - 13s 15ms/step - loss: 1.1244 - accuracy: 0.5782
# Epoch 6/10
# 898/898 [==============================] - 13s 15ms/step - loss: 1.0765 - accuracy: 0.5964
# Epoch 7/10
# 898/898 [==============================] - 16s 17ms/step - loss: 1.0346 - accuracy: 0.6143
# Epoch 8/10
# 898/898 [==============================] - 17s 19ms/step - loss: 0.9746 - accuracy: 0.6347
# Epoch 9/10
# 898/898 [==============================] - 18s 20ms/step - loss: 0.9472 - accuracy: 0.6499
# Epoch 10/10
# 898/898 [==============================] - 14s 16ms/step - loss: 0.8731 - accuracy: 0.6767

# %%
# 클래스 이름 및 데이터 로딩
class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
test_image_data = []
test_labels = []

for class_name in class_names:
    class_folder = os.path.join(dataset_directory, 'test', class_name)
    for image_name in os.listdir(class_folder):
        image_path = os.path.join(class_folder, image_name)
        image = cv2.imread(image_path)  # 그레이스케일로 읽기
        image = cv2.resize(image, (48, 48))  # 이미지 크기 조정
        test_image_data.append(image)
        test_labels.append(class_names.index(class_name))

# 데이터를 NumPy 배열로 변환 및 레이블 One-Hot 인코딩
test_image_data = np.array(test_image_data)
test_image_data = np.expand_dims(test_image_data, axis=-1)  # Conv2D에 맞게 차원 확장
test_labels = to_categorical(test_labels, num_classes=len(class_names))

# %%
#모델 평가
eval_result = model.evaluate(test_image_data, test_labels)
print("Test Loss: {}, Test Accuracy: {}".format(*eval_result))

#테스트 데이터 예측 및 시각화
preds = model.predict(test_image_data)
preds_classes = np.argmax(preds, axis=1)
y_test_classes = np.argmax(test_labels, axis=1)

# 시각화할 이미지 개수
num_images = 5
samples_to_display = np.random.choice(test_image_data.shape[0], num_images, replace=False)

# 테스트 데이터 중 일부 이미지 시각화
for i, idx in enumerate(samples_to_display):
    img = test_image_data[idx].squeeze()  # 차원 축소
    true_label = y_test_classes[idx]
    pred_label = preds_classes[idx]
    plt.figure(figsize=(5, 3))
    plt.imshow(img, cmap='gray')
    plt.title(f"True: {class_names[true_label]}, Pred: {class_names[pred_label]}")
    plt.axis('off')
    plt.show()
# Out:
# 225/225 [==============================] - 2s 8ms/step - loss: 1.0666 - accuracy: 0.6140
# Test Loss: 1.0666348934173584, Test Accuracy: 0.6139593124389648
# 225/225 [==============================] - 1s 4ms/step
